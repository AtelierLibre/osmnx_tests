# %% [markdown]
# # 40 XMLs from [openstreetmap.org](https://www.openstreetmap.org)
#
# ***2 Sep 2020***
#
# - Primarily for visual comparison with [openstreetmap.org](https://www.openstreetmap.org)
# - this notebook processes a selection of XML extracts downloaded from [openstreetmap.org](https://www.openstreetmap.org)
#
# ### Notes
#
# - When processing the XMLs the whole of the XML has to processed, the tag filters can only be applied at the end
#     - This means the area that can be processed from an XML may be quite small before memory issues are encountered
# - Quite a large amount of geometry may need to be processed to extract quite a small amount of data
#     - Files approximately > 90MB caused the kernel to crash
# - Not passing in any tags or polygon will try to process whatever is in the XML to geometry
# - XMLs seem to include clipped, incomplete geometries for example:
#     - a line crossing the boundary will be included but only one node will be included
#     - this causes empty geometries
# - The Overpass API returns all of the data for geometries that overlap the edge of a query area

# %%
# %load_ext autoreload
# %autoreload 2

import geopandas as gpd
import osmnx as ox # using new `geometries` module

ox.utils.config(use_cache=True, log_console=True)

from helper_functions import carto_plot

local_file_path = '/media/nick/WDBlue/osmnx/XML/openstreetmap.org/'

# %% [markdown]
# ## Ilha do Ibo
#
# https://www.openstreetmap.org/#map=12/-12.4193/40.5962

# %%
osmnx_result = ox.geometries_from_xml(local_file_path + 'Ilha_do_Ibo_openstreetmap-org.osm')
osmnx_result = ox.project_gdf(osmnx_result)
osmnx_result.plot(figsize=(12,12), alpha=0.5)
# Out:
# <AxesSubplot:>

# %%
fig,ax = carto_plot(osmnx_result,
                    tags={'place': ['island', 'islet'],
                          'natural': True,
                          'landuse': True,
                          'highway': True})
ax.set_facecolor('#aad3df')
# Out:
# /home/nick/anaconda3/envs/osmnx-dev/lib/python3.6/site-packages/geopandas/plotting.py:532: UserWarning: The GeoDataFrame you are attempting to plot is empty. Nothing has been displayed.
#   UserWarning,
# /home/nick/anaconda3/envs/osmnx-dev/lib/python3.6/site-packages/geopandas/plotting.py:532: UserWarning: The GeoDataFrame you are attempting to plot is empty. Nothing has been displayed.
#   UserWarning,
# /home/nick/anaconda3/envs/osmnx-dev/lib/python3.6/site-packages/geopandas/plotting.py:532: UserWarning: The GeoDataFrame you are attempting to plot is empty. Nothing has been displayed.
#   UserWarning,
# /home/nick/anaconda3/envs/osmnx-dev/lib/python3.6/site-packages/geopandas/plotting.py:532: UserWarning: The GeoDataFrame you are attempting to plot is empty. Nothing has been displayed.
#   UserWarning,

# %% [markdown]
# ## Naberezhnye Chelny
#
# https://www.openstreetmap.org/export#map=15/55.7515/52.4136

# %%
osmnx_result = ox.geometries_from_xml(local_file_path + 'map (1).osm')
osmnx_result = ox.project_gdf(osmnx_result)
osmnx_result.plot(figsize=(12,12), alpha=0.5)
# Out:
# <AxesSubplot:>

# %%
fig,ax = carto_plot(osmnx_result,
                    tags={'leisure': True, 'natural': True, 'landuse': True, 'amenity': True, 'building': True, 'highway': True},
                    left=586500, right=591000, top=6180700, bottom=6178000,
                   )
# Out:
# /home/nick/anaconda3/envs/osmnx-dev/lib/python3.6/site-packages/geopandas/plotting.py:532: UserWarning: The GeoDataFrame you are attempting to plot is empty. Nothing has been displayed.
#   UserWarning,
# /home/nick/anaconda3/envs/osmnx-dev/lib/python3.6/site-packages/geopandas/plotting.py:532: UserWarning: The GeoDataFrame you are attempting to plot is empty. Nothing has been displayed.
#   UserWarning,

# %% [markdown]
# # 5 Medellín
#
# ***XML exported directly from the openstreetmap.org homepage***
#
# https://www.openstreetmap.org/way/123040218#map=17/6.29239/-75.53971

# %%
osmnx_result = ox.geometries_from_xml(local_file_path + 'Medellín.osm')
osmnx_result.plot(figsize=(12,12), alpha=0.3)
# Out:
# <AxesSubplot:>

# %%
fig,ax = carto_plot(osmnx_result,
                    tags={'place': True, 'natural': True, 'landuse': True,
                          'leisure': True, 'amenity': True, 'waterway': True,
                          'highway': True, 'aeroway': True, 'aerialway': True,
                          'building': True, 'shop': True},
                    left=-75.547, right=-75.536,
                    top=6.2965, bottom=6.2876)
# Out:
# /home/nick/anaconda3/envs/osmnx-dev/lib/python3.6/site-packages/geopandas/plotting.py:532: UserWarning: The GeoDataFrame you are attempting to plot is empty. Nothing has been displayed.
#   UserWarning,
# /home/nick/anaconda3/envs/osmnx-dev/lib/python3.6/site-packages/geopandas/plotting.py:532: UserWarning: The GeoDataFrame you are attempting to plot is empty. Nothing has been displayed.
#   UserWarning,
# /home/nick/anaconda3/envs/osmnx-dev/lib/python3.6/site-packages/geopandas/plotting.py:532: UserWarning: The GeoDataFrame you are attempting to plot is empty. Nothing has been displayed.
#   UserWarning,
# /home/nick/anaconda3/envs/osmnx-dev/lib/python3.6/site-packages/geopandas/plotting.py:532: UserWarning: The GeoDataFrame you are attempting to plot is empty. Nothing has been displayed.
#   UserWarning,
# ...

# %% [markdown]
# # 4 Platte - xml
#
# ***XML exported directly from the openstreetmap.org homepage***
#
# https://www.openstreetmap.org/export#map=16/-5.8639/55.3864

# %%
osmnx_result = ox.geometries_from_xml(local_file_path + 'Platte.osm')
osmnx_result.plot(figsize=(8,8), alpha=0.3)
# Out:
# <AxesSubplot:>

# %%
fig,ax = carto_plot(osmnx_result, tags={'place':True,
                                        'natural':True,
                                        'landuse':True,
                                        'leisure':True,
                                        'highway':True,
                                        'aeroway':True,
                                        'building':True})
ax.set_facecolor('#aad3df')
# Out:
# /home/nick/anaconda3/envs/osmnx-dev/lib/python3.6/site-packages/geopandas/plotting.py:532: UserWarning: The GeoDataFrame you are attempting to plot is empty. Nothing has been displayed.
#   UserWarning,
# /home/nick/anaconda3/envs/osmnx-dev/lib/python3.6/site-packages/geopandas/plotting.py:532: UserWarning: The GeoDataFrame you are attempting to plot is empty. Nothing has been displayed.
#   UserWarning,
# /home/nick/anaconda3/envs/osmnx-dev/lib/python3.6/site-packages/geopandas/plotting.py:532: UserWarning: The GeoDataFrame you are attempting to plot is empty. Nothing has been displayed.
#   UserWarning,
# /home/nick/anaconda3/envs/osmnx-dev/lib/python3.6/site-packages/geopandas/plotting.py:532: UserWarning: The GeoDataFrame you are attempting to plot is empty. Nothing has been displayed.
#   UserWarning,
# ...
