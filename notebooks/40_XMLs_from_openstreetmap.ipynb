# %% [markdown]
# # 07 XMLs from openstreetmap.org

# %%
# %load_ext autoreload
# %autoreload 2

import osmnx as ox # using fork `New geometries module - Work In Progress`
ox.utils.config(use_cache=True, log_console=True)

import geopandas as gpd
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', None)

from carto_type_plot import carto_plot

# %% [markdown]
# ## Ilha do Ibo

# %%
gdf = ox.gdf_from_xml('XML/openstreetmap.org/Ilha_do_Ibo_openstreetmap-org.osm')
# Out:
# /home/nick/GitHub/osmnx/osmnx/geometries.py:891: UserWarning: GeoSeries.isna() previously returned True for both missing (None) and empty geometries. Now, it only returns True for missing values. Since the calling GeoSeries contains empty geometries, the result has changed compared to previous versions of GeoPandas.
# Given a GeoSeries 's', you can use 's.is_empty | s.isna()' to get back the old behaviour.
#
# To further ignore this warning, you can do:
# import warnings; warnings.filterwarnings('ignore', 'GeoSeries.isna', UserWarning)
#   gdf = gdf[~(gdf["geometry"].isna() | gdf["geometry"].is_empty)].copy()

# %%
gdf.plot(figsize=(24,24), alpha=0.5)
# Out:
# <AxesSubplot:>

# %%
gdf = ox.project_gdf(gdf)

# %%
fig,ax = carto_plot(gdf, tags={'place': ['island', 'islet'], 'natural': True, 'landuse': True, 'highway': True})
ax.set_facecolor('#aad3df')
# Out:
# /home/nick/anaconda3/envs/osmnx-dev/lib/python3.6/site-packages/geopandas/plotting.py:532: UserWarning: The GeoDataFrame you are attempting to plot is empty. Nothing has been displayed.
#   UserWarning,
# /home/nick/anaconda3/envs/osmnx-dev/lib/python3.6/site-packages/geopandas/plotting.py:532: UserWarning: The GeoDataFrame you are attempting to plot is empty. Nothing has been displayed.
#   UserWarning,
# /home/nick/anaconda3/envs/osmnx-dev/lib/python3.6/site-packages/geopandas/plotting.py:532: UserWarning: The GeoDataFrame you are attempting to plot is empty. Nothing has been displayed.
#   UserWarning,
# /home/nick/anaconda3/envs/osmnx-dev/lib/python3.6/site-packages/geopandas/plotting.py:532: UserWarning: The GeoDataFrame you are attempting to plot is empty. Nothing has been displayed.
#   UserWarning,

# %% [markdown]
# ## https://www.openstreetmap.org/export#map=15/55.7515/52.4136

# %%
gdf = ox.gdf_from_xml('XML/openstreetmap.org/map (1).osm')
# Out:
# /home/nick/GitHub/osmnx/osmnx/geometries.py:891: UserWarning: GeoSeries.isna() previously returned True for both missing (None) and empty geometries. Now, it only returns True for missing values. Since the calling GeoSeries contains empty geometries, the result has changed compared to previous versions of GeoPandas.
# Given a GeoSeries 's', you can use 's.is_empty | s.isna()' to get back the old behaviour.
#
# To further ignore this warning, you can do:
# import warnings; warnings.filterwarnings('ignore', 'GeoSeries.isna', UserWarning)
#   gdf = gdf[~(gdf["geometry"].isna() | gdf["geometry"].is_empty)].copy()

# %%
gdf = ox.project_gdf(gdf)
gdf.plot(figsize=(24,24), alpha=0.5)
# Out:
# <AxesSubplot:>

# %%
fig,ax = carto_plot(gdf,
                    tags={'leisure': True, 'natural': True, 'landuse': True, 'amenity': True, 'building': True, 'highway': True},
                    left=586500, right=591000, top=6180700, bottom=6178000,
                   )
# Out:
# /home/nick/anaconda3/envs/osmnx-dev/lib/python3.6/site-packages/geopandas/plotting.py:532: UserWarning: The GeoDataFrame you are attempting to plot is empty. Nothing has been displayed.
#   UserWarning,
# /home/nick/anaconda3/envs/osmnx-dev/lib/python3.6/site-packages/geopandas/plotting.py:532: UserWarning: The GeoDataFrame you are attempting to plot is empty. Nothing has been displayed.
#   UserWarning,
