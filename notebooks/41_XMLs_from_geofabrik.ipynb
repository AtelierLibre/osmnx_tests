# %% [markdown]
# # 41 XMLs from geofabrik.de
#
# ***2 Sep 2020***
#
# - Primarily for visual comparison with [openstreetmap.org](https://www.openstreetmap.org)
# - this notebook processes a selection of XML extracts downloaded from [geofabrik.de](https://download.geofabrik.de/europe.html)

# %%
# %load_ext autoreload
# %autoreload 2

import geopandas as gpd
import osmnx as ox # using new `geometries` module
ox.utils.config(use_cache=True, log_console=True)

from helper_functions import carto_plot

local_file_path = '/media/nick/WDBlue/osmnx/XML/geofabrik.de/'
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Andorra
#
# https://www.openstreetmap.org/#map=11/42.5455/1.6177

# %%
osmnx_result = ox.geometries_from_xml(local_file_path + 'andorra-latest.osm')
osmnx_result.plot(figsize=(12,12), alpha=0.5)
# Out:
# <AxesSubplot:>

# %%
carto_plot(osmnx_result, top=42.7, bottom=42.4, left=1.4, right=1.8)
# Out:
# /home/nick/anaconda3/envs/osmnx-dev/lib/python3.6/site-packages/geopandas/plotting.py:532: UserWarning: The GeoDataFrame you are attempting to plot is empty. Nothing has been displayed.
#   UserWarning,
# /home/nick/anaconda3/envs/osmnx-dev/lib/python3.6/site-packages/geopandas/plotting.py:532: UserWarning: The GeoDataFrame you are attempting to plot is empty. Nothing has been displayed.
#   UserWarning,
# /home/nick/anaconda3/envs/osmnx-dev/lib/python3.6/site-packages/geopandas/plotting.py:532: UserWarning: The GeoDataFrame you are attempting to plot is empty. Nothing has been displayed.
#   UserWarning,
# /home/nick/anaconda3/envs/osmnx-dev/lib/python3.6/site-packages/geopandas/plotting.py:532: UserWarning: The GeoDataFrame you are attempting to plot is empty. Nothing has been displayed.
#   UserWarning,
# ...

# %% [markdown]
# ## Faroe Islands
#
# https://www.openstreetmap.org/#map=9/61.8911/-6.8362

# %%
osmnx_result = ox.geometries_from_xml(local_file_path + 'faroe-islands-latest.osm')
osmnx_result.plot(figsize=(12,12), alpha=0.5)
# Out:
# <AxesSubplot:>

# %%
fig,ax = carto_plot(osmnx_result, top=62.4, bottom=61.4, left=-7.7, right=-6.2)
ax.set_facecolor('#aad3df')
# Out:
# /home/nick/anaconda3/envs/osmnx-dev/lib/python3.6/site-packages/geopandas/plotting.py:532: UserWarning: The GeoDataFrame you are attempting to plot is empty. Nothing has been displayed.
#   UserWarning,
# /home/nick/anaconda3/envs/osmnx-dev/lib/python3.6/site-packages/geopandas/plotting.py:532: UserWarning: The GeoDataFrame you are attempting to plot is empty. Nothing has been displayed.
#   UserWarning,
# /home/nick/anaconda3/envs/osmnx-dev/lib/python3.6/site-packages/geopandas/plotting.py:532: UserWarning: The GeoDataFrame you are attempting to plot is empty. Nothing has been displayed.
#   UserWarning,
# /home/nick/anaconda3/envs/osmnx-dev/lib/python3.6/site-packages/geopandas/plotting.py:532: UserWarning: The GeoDataFrame you are attempting to plot is empty. Nothing has been displayed.
#   UserWarning,
# ...

# %% [markdown]
# #### Notes:
#
# - the central island was not created because bits of geometry are missing around -7.05, 62.25
# - searching the xml for node/7813627969 for example finds the reference to it from way/159546033 but doesn't find the node itself
# - the issue is with the xml rather than the processing.
# - the tag 'natural': 'coastline' is on the line fragments not on the relation - filling these doesn't make any sense
# - querying the overpass api for 'place': 'island' does create the full polygon for the islands

# %%
faroe_islands_overpass = ox.geometries_from_place('faroe islands', tags={'natural': 'coastline', 'place': 'island'})
ax = faroe_islands_overpass[~faroe_islands_overpass['place'].isna()].plot(figsize=(24,24), alpha=0.5)
faroe_islands_overpass[~faroe_islands_overpass['natural'].isna()].plot(ax=ax, alpha=0.5, color='red')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Guernsey
#
# https://www.openstreetmap.org/#map=11/49.3397/-2.3463

# %%
osmnx_result = ox.geometries_from_xml(local_file_path + 'guernsey-jersey-latest.osm')

# %%
osmnx_result.plot(figsize=(12,12), alpha=0.5)
# Out:
# <AxesSubplot:>

# %%
fig,ax = carto_plot(osmnx_result, left=-2.7, right=-2, bottom=49.1, top=49.52)
ax.set_facecolor('#aad3df')
# Out:
# /home/nick/anaconda3/envs/osmnx-dev/lib/python3.6/site-packages/geopandas/plotting.py:532: UserWarning: The GeoDataFrame you are attempting to plot is empty. Nothing has been displayed.
#   UserWarning,
# /home/nick/anaconda3/envs/osmnx-dev/lib/python3.6/site-packages/geopandas/plotting.py:532: UserWarning: The GeoDataFrame you are attempting to plot is empty. Nothing has been displayed.
#   UserWarning,
# /home/nick/anaconda3/envs/osmnx-dev/lib/python3.6/site-packages/geopandas/plotting.py:532: UserWarning: The GeoDataFrame you are attempting to plot is empty. Nothing has been displayed.
#   UserWarning,
# /home/nick/anaconda3/envs/osmnx-dev/lib/python3.6/site-packages/geopandas/plotting.py:532: UserWarning: The GeoDataFrame you are attempting to plot is empty. Nothing has been displayed.
#   UserWarning,
# ...

# %% [markdown]
# ## Liechtenstein
#
# https://www.openstreetmap.org/#map=12/47.1505/9.5869

# %%
osmnx_result = ox.geometries_from_xml(local_file_path + 'liechtenstein-latest.osm')
osmnx_result.plot(figsize=(12,12), alpha=0.5)
# Out:
# <AxesSubplot:>

# %%
carto_plot(osmnx_result, bottom=47, top=47.3, left=9.45, right=9.65)
# Out:
# /home/nick/anaconda3/envs/osmnx-dev/lib/python3.6/site-packages/geopandas/plotting.py:532: UserWarning: The GeoDataFrame you are attempting to plot is empty. Nothing has been displayed.
#   UserWarning,
# /home/nick/anaconda3/envs/osmnx-dev/lib/python3.6/site-packages/geopandas/plotting.py:532: UserWarning: The GeoDataFrame you are attempting to plot is empty. Nothing has been displayed.
#   UserWarning,
# /home/nick/anaconda3/envs/osmnx-dev/lib/python3.6/site-packages/geopandas/plotting.py:532: UserWarning: The GeoDataFrame you are attempting to plot is empty. Nothing has been displayed.
#   UserWarning,
# /home/nick/anaconda3/envs/osmnx-dev/lib/python3.6/site-packages/geopandas/plotting.py:532: UserWarning: The GeoDataFrame you are attempting to plot is empty. Nothing has been displayed.
#   UserWarning,
# ...

# %% [markdown]
# ## Monaco
#
# https://www.openstreetmap.org/#map=15/43.7381/7.4209

# %%
osmnx_result = ox.geometries_from_xml(local_file_path + 'monaco-latest.osm')
osmnx_result.plot(figsize=(12,12), alpha=0.5)
# Out:
# <AxesSubplot:>

# %%
fig,ax = carto_plot(osmnx_result, bottom=43.72, top=43.76, left=7.4, right=7.45)
ax.set_facecolor('#aad3df')
# Out:
# /home/nick/anaconda3/envs/osmnx-dev/lib/python3.6/site-packages/geopandas/plotting.py:532: UserWarning: The GeoDataFrame you are attempting to plot is empty. Nothing has been displayed.
#   UserWarning,
# /home/nick/anaconda3/envs/osmnx-dev/lib/python3.6/site-packages/geopandas/plotting.py:532: UserWarning: The GeoDataFrame you are attempting to plot is empty. Nothing has been displayed.
#   UserWarning,
# /home/nick/anaconda3/envs/osmnx-dev/lib/python3.6/site-packages/geopandas/plotting.py:532: UserWarning: The GeoDataFrame you are attempting to plot is empty. Nothing has been displayed.
#   UserWarning,
# /home/nick/anaconda3/envs/osmnx-dev/lib/python3.6/site-packages/geopandas/plotting.py:532: UserWarning: The GeoDataFrame you are attempting to plot is empty. Nothing has been displayed.
#   UserWarning,
# ...
